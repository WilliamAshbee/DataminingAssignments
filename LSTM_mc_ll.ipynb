# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/DataminingAssignments/blob/main/LSTM_mc_ll.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):
    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}


def plot_all( sample = None, model = None, labels = None):
    img = sample[:,:].squeeze().cpu().numpy()
    #img = img.T
    plt.imshow(img, cmap=plt.cm.gray_r)
    if model != None:
        with torch.no_grad():
            global numpoints
            print(labels.shape,sample.shape)
            sample = torch.stack([sample for i in range(2)],dim = 0).cuda()
            labels = torch.stack([labels for i in range(2)],dim = 0).cuda()
            h0 = None
            c0 = None
            X = []
            Y = []
            for i in range(19):
              out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
              X.extend(out[0,:,0].tolist())
              Y.extend(out[0,:,1].tolist())

            predres = len(X)

            s = [.001 for x in range(predres)]
            
            assert len(s) == predres
            c = ['red' for x in range(predres)]
            assert len(c) == predres
            #print("type",type(X))
            ascatter = plt.scatter(X,Y,s = s,c = c)
            plt.gca().add_artist(ascatter)
    else:
        #print(labels.shape)
        X = labels[:,0]
        Y = labels[:,1]
        #print(X.shape)
        #print(Y.shape)
        s = [.001 for x in range(numpoints)]
        #print(len(s))
        c = ['red' for x in range(numpoints)]
        #print(len(c))
        ascatter = plt.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
        plt.gca().add_artist(ascatter)

class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        z = torch.zeros(numpoints,1)
        #print(z.shape)
        points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,dataset, model):
        #model.setBatchSize(batch_size = 1)
        for i in range(100):
            sample, labels = dataset[i]
            plt.subplot(10,10,i+1)
            plot_all(sample = sample,model=model, labels = labels)
            plt.axis('off')
        plt.savefig(title,dpi=600)

dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
dataset = DonutDataset(length = 64*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1280, 1]) torch.Size([1280, 1]) torch.Size([1280, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# I think I need to give the model the first x0,y0 coordinate in addition to all the other information.
#
# Ablation:\
# Network depth helps\
# Network width helps\
# Probably lower learning rate and long running times helps \
# \
# note:\
# worth noting one of the ameba columns always starts at the same place

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 50
        self.lm_len = 20
        self.longtermMem = None
        self.longtermMemP = None
        # lstm cell
        self.lstm_cell = nn.LSTM(2, self.hidden_size,self.num_layers)

        self.embedimage = nn.Sequential(
            nn.Linear(1024+self.hidden_size*2,256),
            nn.ReLU()
        )

        
        self.fc_out = nn.Sequential(
            nn.Linear(self.hidden_size*4,2),
            nn.Sigmoid()
        )
        self.alpharead = nn.Sequential(
            nn.Linear((self.lm_len+2)*self.hidden_size,self.lm_len),
            nn.Softmax()
        )
        self.alphashort = nn.Sequential(
            nn.Linear((self.seq_len+1)*self.hidden_size,50),
            nn.Softmax()
        )

        self.alphawrite = nn.Sequential(
            nn.Linear((self.seq_len+2)*self.hidden_size,self.seq_len),
            nn.Softmax()
        )
        


        self.hiddenMlp = nn.Sequential(
            nn.Linear(1024+2,self.hidden_size),nn.ReLU())
        self.cellMlp = nn.Sequential(
            nn.Linear(1024+2,self.hidden_size),nn.ReLU())
        

            
        
    def forward(self, features, captions,h0 = None, c0= None,ind = 0):

        
        self.track +=1
        batch_size = features.size(0)
        if h0 == None:
          self.longtermMem = torch.zeros((batch_size,  self.hidden_size,20)).cuda()
        else:
          self.longtermMem = self.longtermMem.detach()
        

        img_emb = torch.empty((batch_size, captions.size(1), self.hidden_size)).cuda()
        
        p0 = torch.flatten(captions[:,0,:2],start_dim=1)
        out = p0

                
        if h0 == None or c0 == None:
          h0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
          c0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
        
        
        if self.num_layers>1 and h0.shape[0] == 1:
          h0 = torch.stack([h0.squeeze() for i in range(self.num_layers)],dim = 0)
          c0 = torch.stack([c0.squeeze() for i in range(self.num_layers)],dim = 0)
        
        #print(h0.shape)
        #print("1")
        outputs = torch.empty((batch_size, captions.size(1), 2)).cuda()
        
        
        for t in range(captions.size(1)):
        
            # for the first time step the input is the feature vector
            if t == 0:
                output, (hidden_state, cell_state) = self.lstm_cell(p0.unsqueeze(0), (h0, c0))
            else:
                output, (hidden_state, cell_state) = self.lstm_cell(out.unsqueeze(0), (hidden_state, cell_state))
                
                
            assert h0 != None

            #print("2")
        
            emb = self.embedimage(torch.cat([torch.flatten(features,start_dim=1),output.squeeze(),hidden_state[-1,:,:].squeeze()],dim=1))
            img_emb[:, t, :] = emb
            #print("3")
        
            if t ==49:
              #print('49')
              aw_in = torch.cat([torch.flatten(img_emb.clone(),start_dim=1),emb.squeeze(),hidden_state[-1,:,:].squeeze()],dim=1)
              #print(aw_in.shape)
              alphawrite = self.alphawrite(aw_in)
              #print(img_emb.shape,alphawrite.shape)
              outeswritea = img_emb.clone()*alphawrite.unsqueeze(2)
              outeswrite = torch.sum(outeswritea,dim=1)
            
              self.longtermMem[:,:,ind]=outeswrite
            
            ar_in = torch.cat([torch.flatten(self.longtermMem,start_dim=1),emb.squeeze(),hidden_state[-1,:,:].squeeze()],dim=1)
            
            #print("4",ar_in.shape,torch.flatten(self.longtermMem,start_dim=1).shape, emb.shape,hidden_state[-1,:,:].shape)
            alpharead = self.alpharead(ar_in)
            #print('4.1',self.longtermMem.shape,alpharead.unsqueeze(1).shape)
            outesreada = self.longtermMem.clone()*alpharead.unsqueeze(1)
            #print('4.2',outesreada.shape)
            
            outesread = torch.sum(outesreada,dim=2)

            #print("5")
        
            
            alph = self.alphashort(torch.cat([hidden_state[-1,:,:],torch.flatten(img_emb.clone(),start_dim=1)],dim=1))
            outesalpha = img_emb.clone()*alph.unsqueeze(2)
            #print("6")
        
            outeshort = torch.sum(outesalpha,dim=1)
            #print('6.1',outesread.shape,outeshort.shape,hidden_state[-1,:,:].shape,emb.shape)
            combOut = torch.cat([outesread, outeshort,hidden_state[-1,:,:].detach().clone(),emb],dim=1)
            #print("7",combOut.shape)
        
            out = self.fc_out(combOut)
            
            # build the output tensor

            outputs[:, t, :] = out
        #print(h0.shape,hidden_state.shape)
            
        return 32.0*outputs, hidden_state.detach().clone(), cell_state.detach().clone()#, captions

# %%
a = torch.ones(64,256,50)
b = torch.from_numpy(np.random.randn(50))
c = a*b
print(c[0,1,:])
print(c[1,1,:])
# Out:
# tensor([-0.7433,  0.1414,  0.1328,  1.0917, -0.1294, -0.5928,  0.3276, -1.0255,
#          0.1311, -0.5717,  1.5429,  1.4025,  1.0462,  0.1045,  0.1415, -1.3599,
#          0.4462, -0.0115, -0.7164,  1.2382,  1.3439, -0.1395,  1.7261,  0.1295,
#         -0.0563,  0.0347, -0.1415,  0.5175,  0.9476, -0.9228,  1.0833,  0.6206,
#          0.3046, -1.2020, -0.5343,  0.7938,  0.0555, -0.0699, -1.9979,  0.2680,
#         -0.2406,  1.2085, -0.2453, -0.0173,  0.7869,  0.8916,  0.5380,  0.2881,
#         -0.7214,  0.0935], dtype=torch.float64)
# tensor([-0.7433,  0.1414,  0.1328,  1.0917, -0.1294, -0.5928,  0.3276, -1.0255,
#          0.1311, -0.5717,  1.5429,  1.4025,  1.0462,  0.1045,  0.1415, -1.3599,
#          0.4462, -0.0115, -0.7164,  1.2382,  1.3439, -0.1395,  1.7261,  0.1295,
#         -0.0563,  0.0347, -0.1415,  0.5175,  0.9476, -0.9228,  1.0833,  0.6206,
#          0.3046, -1.2020, -0.5343,  0.7938,  0.0555, -0.0699, -1.9979,  0.2680,
#         -0.2406,  1.2085, -0.2453, -0.0173,  0.7869,  0.8916,  0.5380,  0.2881,
#         -0.7214,  0.0935], dtype=torch.float64)

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
model = model.train()
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0
# tensor(43.6641, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(42.6658, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(43.0529, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(43.7764, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(44.6378, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(43.8020, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(48.1724, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(46.4311, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(45.5050, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(47.7022, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(44.3451, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(43.2225, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(45.8806, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(45.7043, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(50.3091, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(45.8817, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(48.5740, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(47.4725, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(48.1892, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(47.0058, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(48.4991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(47.8443, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(49.3414, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(50.8549, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(47.7789, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(47.1289, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(47.6651, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(46.0774, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(48.2386, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(48.8964, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(46.7335, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(48.9832, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(48.1496, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(46.0377, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(45.9629, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(46.2396, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(48.7214, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(48.7998, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(46.5919, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(49.1388, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(48.0647, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(47.4405, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(50.3514, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(48.3013, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(48.0312, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(46.0828, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(46.6336, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(43.5666, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(46.9507, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(41.4394, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(39.9028, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(35.3367, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(33.1163, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(27.8578, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(25.4935, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(21.6181, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(22.1996, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(18.3433, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(19.3829, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(14.9748, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(15.8285, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(13.1644, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(11.9205, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(11.7406, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(12.5681, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(11.5171, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(11.1198, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(10.7888, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(11.2221, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(11.2476, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(10.9382, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(11.3169, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(11.8054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(12.4197, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(12.8100, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(15.6339, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(24.8771, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(15.5041, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(14.5046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(14.0926, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(14.3999, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(14.0320, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(14.4580, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(14.1056, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(13.9841, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(15.1913, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(13.2926, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(12.8398, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(14.5656, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(13.9277, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(13.2799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(12.4354, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(12.5937, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(12.3258, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(12.6786, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(11.9558, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(12.3870, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(12.3891, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(12.1453, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(12.1015, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(11.4792, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(11.0312, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(10.6136, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(11.4153, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(10.5125, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(11.1664, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(10.0868, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(9.7495, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(10.3285, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(10.0791, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(9.8520, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(9.2051, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(8.5112, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(8.9903, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(9.3434, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(7.8289, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(6.4452, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(5.4440, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(7.5822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(7.6220, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(6.2160, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(5.4512, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(4.6199, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(4.0292, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(4.3026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(4.4957, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(4.2784, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(4.5397, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.5639, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.5176, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.9432, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.6714, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(4.4320, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.7366, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.1399, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.0910, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.0786, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.5951, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.7315, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.7577, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(3.2277, device='cuda:0', grad_fn=<MeanBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b5d8f0c26f72> in <module>()
#      11       optimizer.zero_grad()
#      12
# ---> 13       out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
#      14       loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
#      15       writer.add_scalar("Loss/train", loss, epoch)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-4-f4a74e3e2373> in forward(self, features, captions, h0, c0, ind)
#      89                 output, (hidden_state, cell_state) = self.lstm_cell(p0.unsqueeze(0), (h0, c0))
#      90             else:
# ---> 91                 output, (hidden_state, cell_state) = self.lstm_cell(out.unsqueeze(0), (hidden_state, cell_state))
#      92
#      93
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     660         if batch_sizes is None:
#     661             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 662                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     663         else:
#     664             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
model = model.train()
for epoch in range (5):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      #print(x.shape,y.shape)

      out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.000001, betas = (.9,.999))#ideal

# %%
model = model.train()
for epoch in range (5):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      #print(x.shape,y.shape)

      out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)

# %%
model = model.eval()
for epoch in range (1):
  loss = None
  for x,y in loader_test:
    h0 = None
    c0 = None
    loss = torch.zeros(19)
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      #print(x.shape,y.shape)

      out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      
      loss[i] = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      print(loss[i])
      writer.add_scalar("Loss/val", loss[i],i, epoch)

    #print(y[:,0,:2])
    print('epoch',epoch)
    print('test loss', torch.mean(loss))

# %%
writer.flush()
writer.close()

# %% [markdown]
# **started** with .0001 then moved to .00001 learning rate (20 epochs)
# finished with .000001 lr, but didn't see much more improvement (total 60 epochs 20,20,20) extra 20 over previous comment

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
pred_dataset = DonutDataset(length = 100)

# %%
DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)
