# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/DataminingAssignments/blob/main/LSTM_attention_memory_regressor2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):
    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}


def plot_all( sample = None, model = None, labels = None):
    img = sample[:,:].squeeze().cpu().numpy()
    #img = img.T
    plt.imshow(img, cmap=plt.cm.gray_r)
    if model != None:
        with torch.no_grad():
            global numpoints
            print(labels.shape,sample.shape)
            sample = torch.stack([sample for i in range(2)],dim = 0).cuda()
            labels = torch.stack([labels for i in range(2)],dim = 0).cuda()
            h0 = None
            c0 = None
            X = []
            Y = []
            for i in range(19):
              if i == 0:
                out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,out = None)
              else:
                out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,out = o)
              X.extend(out[0,:,0].tolist())
              Y.extend(out[0,:,1].tolist())

            predres = len(X)

            s = [.001 for x in range(predres)]
            
            assert len(s) == predres
            c = ['red' for x in range(predres)]
            assert len(c) == predres
            #print("type",type(X))
            ascatter = plt.scatter(X,Y,s = s,c = c)
            plt.gca().add_artist(ascatter)
    else:
        #print(labels.shape)
        X = labels[:,0]
        Y = labels[:,1]
        #print(X.shape)
        #print(Y.shape)
        s = [.001 for x in range(numpoints)]
        #print(len(s))
        c = ['red' for x in range(numpoints)]
        #print(len(c))
        ascatter = plt.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
        plt.gca().add_artist(ascatter)

class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        z = torch.zeros(numpoints,1)
        #print(z.shape)
        points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,dataset, model):
        #model.setBatchSize(batch_size = 1)
        for i in range(100):
            sample, labels = dataset[i]
            plt.subplot(10,10,i+1)
            plot_all(sample = sample,model=model, labels = labels)
            plt.axis('off')
        plt.savefig(title,dpi=600)

dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
dataset = DonutDataset(length = 64*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1280, 1]) torch.Size([1280, 1]) torch.Size([1280, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# I think I need to give the model the first x0,y0 coordinate in addition to all the other information.
#
# Ablation:\
# Network depth helps\
# Network width helps\
# Probably lower learning rate and long running times helps \
# \
# note:\
# worth noting one of the ameba columns always starts at the same place

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 50
        self.lm_len = 20
        self.longtermMem = None
        self.longtermMemP = None
        # lstm cell
        self.lstm_cell = nn.LSTM(2+256, self.hidden_size,self.num_layers)

        self.embedimage = nn.Sequential(
            nn.Linear(1024+2,256),
            nn.ReLU()
        )
        self.embedimage2 = nn.Sequential(
            nn.Linear(1024+self.hidden_size*2+2,256),
            nn.ReLU()
        )
        
        self.fc_out = nn.Sequential(
            nn.Linear(self.hidden_size*3+2,2),
            nn.Sigmoid()
        )
        """
        self.alpharead = nn.Sequential(
            nn.Linear((self.lm_len+2)*self.hidden_size,self.lm_len),
            nn.Softmax()
        )
        self.alphashort = nn.Sequential(
            nn.Linear((self.seq_len+1)*self.hidden_size,50),
            nn.Softmax()
        )

        self.alphawrite = nn.Sequential(
            nn.Linear((self.seq_len+2)*self.hidden_size,self.seq_len),
            nn.Softmax()
        )
        """
        


        self.hiddenMlp = nn.Sequential(
            nn.Linear(1024+2,self.hidden_size),nn.ReLU())
        self.cellMlp = nn.Sequential(
            nn.Linear(1024+2,self.hidden_size),nn.ReLU())
        

            
        
    def forward(self, features, captions,h0 = None, c0= None,ind = 0,out = None):

        
        self.track +=1
        batch_size = features.size(0)
        if h0 == None:
          self.longtermMem = torch.zeros((batch_size,  self.hidden_size,20)).cuda()
        else:
          self.longtermMem = self.longtermMem.detach()
        

        img_emb = torch.empty((batch_size, captions.size(1), self.hidden_size)).cuda()
        
        p0 = torch.flatten(captions[:,0,:2],start_dim=1)
        if out == None:
          out = p0
        

                
        if h0 == None or c0 == None:
          h0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
          c0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
        
        
        if self.num_layers>1 and h0.shape[0] == 1:
          h0 = torch.stack([h0.squeeze() for i in range(self.num_layers)],dim = 0)
          c0 = torch.stack([c0.squeeze() for i in range(self.num_layers)],dim = 0)
        
        #print(h0.shape)
        #print("1")
        outputs = torch.empty((batch_size, captions.size(1), 2)).cuda()
        
            
        for t in range(captions.size(1)):
            emb = self.embedimage(torch.cat([torch.flatten(features,start_dim=1),out],dim=1))

            # for the first time step the input is the feature vector
            if t == 0:
                output, (hidden_state, cell_state) = self.lstm_cell(torch.cat([p0,emb],dim=1).unsqueeze(0), (h0, c0))
            else:
                output, (hidden_state, cell_state) = self.lstm_cell(torch.cat([p0,emb],dim=1).unsqueeze(0), (hidden_state, cell_state))
                
                
            assert h0 != None

            #print("2")
        
            emb2_in = torch.cat([torch.flatten(features,start_dim=1),output.squeeze(),hidden_state[-1,:,:].squeeze(),out],dim=1)
            #print('emb2_in',emb2_in.shape)
            emb2 = self.embedimage2(emb2_in)
            #print("3",output.shape,hidden_state[-1,:,:].shape,emb2.shape)
        
            
            
            comb_out = torch.cat([output.squeeze(), hidden_state[-1,:,:].detach().clone(),emb2,out],dim=1)
            
            
            #print("4",comb_out.shape)

            out = self.fc_out(comb_out)
            
            # build the output tensor

            outputs[:, t, :] = out
        #print(h0.shape,hidden_state.shape)
            
        return 32.0*outputs, hidden_state.detach().clone(), cell_state.detach().clone(),out.detach().clone()#, captions

# %%
a = torch.ones(64,256,50)
b = torch.from_numpy(np.random.randn(50))
c = a*b
print(c[0,1,:])
print(c[1,1,:])
# Out:
# tensor([-0.8085, -0.0920, -2.5421,  0.8554,  0.5773,  0.3282, -1.0273, -1.2428,
#          0.8390,  0.5646, -0.7264,  0.5903, -0.4975, -0.0921, -0.1603,  0.1738,
#         -0.3105,  0.8352, -1.4389, -0.6118,  0.8374, -0.2261, -0.5810, -0.0474,
#          0.6815, -0.3859,  0.4328,  1.0378,  1.6323,  0.3821, -0.4681, -0.1390,
#         -0.4306,  0.4227,  0.5341,  1.3592, -0.9719, -0.2900,  0.3026, -0.0982,
#         -0.0580,  1.0831,  0.2358,  1.3763,  0.5592,  0.0687, -0.9706,  0.3016,
#          0.0709, -0.9139], dtype=torch.float64)
# tensor([-0.8085, -0.0920, -2.5421,  0.8554,  0.5773,  0.3282, -1.0273, -1.2428,
#          0.8390,  0.5646, -0.7264,  0.5903, -0.4975, -0.0921, -0.1603,  0.1738,
#         -0.3105,  0.8352, -1.4389, -0.6118,  0.8374, -0.2261, -0.5810, -0.0474,
#          0.6815, -0.3859,  0.4328,  1.0378,  1.6323,  0.3821, -0.4681, -0.1390,
#         -0.4306,  0.4227,  0.5341,  1.3592, -0.9719, -0.2900,  0.3026, -0.0982,
#         -0.0580,  1.0831,  0.2358,  1.3763,  0.5592,  0.0687, -0.9706,  0.3016,
#          0.0709, -0.9139], dtype=torch.float64)

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
model = model.train()
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i ==0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,out = o)
        
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 0
# tensor(54.5226, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(31.5416, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(12.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(2.7630, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(4.3713, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(4.8945, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(6.0235, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(12.4016, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(2.1738, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(11.0656, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(16.4472, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(9.4381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(7.6174, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(2.2033, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(2.7326, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(2.2116, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.6892, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(2.0011, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.5779, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(2.2683, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.6674, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.7153, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.4181, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.6847, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.6935, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(3.3438, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(6.3615, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(3.4034, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(6.5151, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.5469, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.3346, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.4770, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.5101, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.9210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.5479, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(3.1245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.5222, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(3.6981, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.3449, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.6972, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.3740, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.4349, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(4.8467, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(9.7396, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(8.2660, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(7.9128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.6072, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.4021, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.4359, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.6575, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.4722, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.5826, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.4665, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2303, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.7159, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1337, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2787, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.3269, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.4645, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.0361, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.0804, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.5621, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.1270, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.8841, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.4222, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.5575, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.3059, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.7448, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.2656, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.9553, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(3.3648, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.2736, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(3.2292, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.5227, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.1749, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.4449, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.4852, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1408, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.5984, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.0248, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(2.4992, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(4.6105, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.8462, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(3.7951, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.3192, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.8320, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1596, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.3366, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.5304, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.5128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.7042, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.8094, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(2.6059, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.9358, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(2.7168, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.5248, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.4842, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0774, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.4774, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(2.1075, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.5328, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.8636, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.9592, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.0205, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.5301, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.6299, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.4072, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.8393, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.4029, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.3991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.3987, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.4873, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.9938, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.9814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.2166, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.8726, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.7385, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.4061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.8893, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.2878, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.3431, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.2149, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.7828, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.7528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.4665, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.8124, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.4348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.6809, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.3280, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.1617, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.2361, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.6707, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.5434, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(4.4017, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(5.5797, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(5.1913, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(6.6471, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.2392, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.7545, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.3649, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.0337, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.8031, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.2632, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.8429, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.4743, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.0432, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.4336, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.7593, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.3462, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.4682, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.2126, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.4612, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.2791, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1987, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.2759, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.3005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.4357, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.5086, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.3769, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.7684, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(2.6262, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.6610, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(2.6272, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.6020, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(2.0011, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.5501, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.5289, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.5128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.4824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.9757, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(2.0601, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(3.2361, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.8282, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(3.0612, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.2041, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.7912, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1761, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.2647, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.2310, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1916, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.2989, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.2225, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.7055, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.3987, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(2.1730, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.9413, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(2.5105, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.5100, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.8381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.4251, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.5706, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.2569, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.2937, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.2571, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.2168, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.5482, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.4246, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(2.3412, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(2.2624, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(3.6505, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
model = model.train()
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i ==0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,out = o)
        
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 0
# tensor(2.2373, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.6736, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.4232, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.3516, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2366, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2803, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2523, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.3481, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2109, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1937, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1817, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0846, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0507, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2947, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0127, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1581, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2164, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1003, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1399, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2084, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2807, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.3653, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2012, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0906, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1056, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0785, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2414, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0817, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1489, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0992, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1382, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0345, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1184, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1272, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0770, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2682, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0943, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1739, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1673, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1866, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1635, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2484, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1280, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.3123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2597, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1155, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(0.9800, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1296, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1181, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0442, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1796, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0538, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2211, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1422, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1835, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0732, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0563, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0260, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0646, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1272, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2518, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1612, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1029, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1038, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2223, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1488, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1108, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2360, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1464, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0926, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1706, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0573, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0849, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0795, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2003, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1446, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(0.9278, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1723, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1722, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1531, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2024, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2110, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1586, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(0.9002, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2039, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0835, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0509, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0916, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(0.9954, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0833, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2011, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1558, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0430, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1387, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2368, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.0272, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.2283, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(0.9677, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(0.9779, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(0.9865, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1021, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.2779, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1806, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1731, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.4183, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1668, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1416, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1511, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1341, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.2280, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1721, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.0552, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(0.9759, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.2121, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1304, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(0.9844, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.2736, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.0801, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.1402, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(0.9849, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.0801, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.1112, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(0.9812, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(0.9652, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.0023, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.0327, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.1273, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.2116, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.1345, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.1584, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.1107, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.1767, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.0217, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.1970, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.3130, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.2550, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.0513, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1653, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1172, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1584, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(0.9876, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.0731, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(0.9477, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1893, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1219, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1416, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1617, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.0283, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.0468, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.0862, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(0.9863, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.0102, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1176, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.1077, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.0761, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1864, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.0540, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.0732, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1928, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1595, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1869, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1099, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.0825, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(0.8949, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.0076, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.2274, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1135, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.0917, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.0828, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.0548, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.0606, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.0996, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1190, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.1363, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1648, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1332, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1743, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1432, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1948, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.0177, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1216, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.0421, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1032, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(0.9963, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1039, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.0383, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.0472, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.0875, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1097, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.0179, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(0.9950, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.0350, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9
# tensor(1.1105, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.000001, betas = (.9,.999))#ideal

# %%
model = model.train()
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i ==0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,out = o)
        
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 0
# tensor(1.1369, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(0.9832, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1586, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0537, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1317, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0920, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1050, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1044, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0194, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1544, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0417, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0597, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0725, device='cuda:0', grad_fn=<MeanBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-145-fb182b514144> in <module>()
#      19       writer.add_scalar("Loss/train", loss, epoch)
#      20
# ---> 21       loss.backward()
#      22       optimizer.step()
#      23     #print(y[:,0,:2])
#
# /usr/local/lib/python3.7/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     148
#     149
#
# KeyboardInterrupt:

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)

# %%
model = model.eval()
for epoch in range (1):
  loss = None
  for x,y in loader_test:
    h0 = None
    c0 = None
    loss = torch.zeros(19)
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      #print(x.shape,y.shape)

      out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      
      loss[i] = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      print(loss[i])
      writer.add_scalar("Loss/val", loss[i],i, epoch)

    #print(y[:,0,:2])
    print('epoch',epoch)
    print('test loss', torch.mean(loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# tensor(0.9777, grad_fn=<SelectBackward>)
# tensor(1.1725, grad_fn=<SelectBackward>)
# tensor(1.3843, grad_fn=<SelectBackward>)
# tensor(1.4620, grad_fn=<SelectBackward>)
# tensor(1.7478, grad_fn=<SelectBackward>)
# tensor(1.5057, grad_fn=<SelectBackward>)
# tensor(1.5500, grad_fn=<SelectBackward>)
# tensor(1.3419, grad_fn=<SelectBackward>)
# tensor(1.2511, grad_fn=<SelectBackward>)
# tensor(1.1219, grad_fn=<SelectBackward>)
# tensor(1.0758, grad_fn=<SelectBackward>)
# tensor(1.1057, grad_fn=<SelectBackward>)
# tensor(1.0842, grad_fn=<SelectBackward>)
# tensor(1.0477, grad_fn=<SelectBackward>)
# tensor(1.1306, grad_fn=<SelectBackward>)
# tensor(1.2420, grad_fn=<SelectBackward>)
# tensor(1.2588, grad_fn=<SelectBackward>)
# tensor(1.4047, grad_fn=<SelectBackward>)
# tensor(1.2877, grad_fn=<SelectBackward>)
# epoch 0
# test loss tensor(1.2712, grad_fn=<MeanBackward0>)

# %%
writer.flush()
writer.close()

# %% [markdown]
# **started** with .0001 then moved to .00001 learning rate (20 epochs)
# finished with .000001 lr, but didn't see much more improvement (total 60 epochs 20,20,20) extra 20 over previous comment

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)
# Out:
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
