# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/DataminingAssignments/blob/main/LSTM_attention_memory_regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):
    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}


def plot_all( sample = None, model = None, labels = None):
    img = sample[:,:].squeeze().cpu().numpy()
    #img = img.T
    plt.imshow(img, cmap=plt.cm.gray_r)
    if model != None:
        with torch.no_grad():
            global numpoints
            print(labels.shape,sample.shape)
            sample = torch.stack([sample for i in range(2)],dim = 0).cuda()
            labels = torch.stack([labels for i in range(2)],dim = 0).cuda()
            h0 = None
            c0 = None
            X = []
            Y = []
            for i in range(19):
              out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
              X.extend(out[0,:,0].tolist())
              Y.extend(out[0,:,1].tolist())

            predres = len(X)

            s = [.001 for x in range(predres)]
            
            assert len(s) == predres
            c = ['red' for x in range(predres)]
            assert len(c) == predres
            #print("type",type(X))
            ascatter = plt.scatter(X,Y,s = s,c = c)
            plt.gca().add_artist(ascatter)
    else:
        #print(labels.shape)
        X = labels[:,0]
        Y = labels[:,1]
        #print(X.shape)
        #print(Y.shape)
        s = [.001 for x in range(numpoints)]
        #print(len(s))
        c = ['red' for x in range(numpoints)]
        #print(len(c))
        ascatter = plt.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
        plt.gca().add_artist(ascatter)

class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        z = torch.zeros(numpoints,1)
        #print(z.shape)
        points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,dataset, model):
        #model.setBatchSize(batch_size = 1)
        for i in range(100):
            sample, labels = dataset[i]
            plt.subplot(10,10,i+1)
            plot_all(sample = sample,model=model, labels = labels)
            plt.axis('off')
        plt.savefig(title,dpi=600)

dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
dataset = DonutDataset(length = 64*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1280, 1]) torch.Size([1280, 1]) torch.Size([1280, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# I think I need to give the model the first x0,y0 coordinate in addition to all the other information.
#
# Ablation:\
# Network depth helps\
# Network width helps\
# Probably lower learning rate and long running times helps \
# \
# note:\
# worth noting one of the ameba columns always starts at the same place

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 50
        self.longtermMem = None
        self.longtermMemP = None
        # lstm cell
        self.lstm_cell = nn.LSTM(2, self.hidden_size,self.num_layers)

        self.embedimage = nn.Sequential(
            nn.Linear(1024+self.hidden_size,256),
            nn.ReLU()
        )

        
        self.fc_out = nn.Sequential(
            nn.Linear(20*self.hidden_size+self.hidden_size*3,2),
            nn.Sigmoid()
        )
        self.alpha = nn.Sequential(
            nn.Linear(self.seq_len*self.hidden_size,50),
            nn.Softmax()
        )
        


        self.hiddenMlp = nn.Sequential(
            nn.Linear(1024+2,self.hidden_size),nn.ReLU())
        self.cellMlp = nn.Sequential(
            nn.Linear(1024+2,self.hidden_size),nn.ReLU())
        

            
        
    def forward(self, features, captions,h0 = None, c0= None,ind = 0):

        
        self.track +=1
        batch_size = features.size(0)
        if h0 == None:
          self.longtermMem = torch.zeros((batch_size,  self.hidden_size,20)).cuda()
        else:
          self.longtermMem = self.longtermMem.detach()
        

        img_emb = torch.empty((batch_size, captions.size(1), self.hidden_size)).cuda()
        
        p0 = torch.flatten(captions[:,0,:2],start_dim=1)
        out = p0

                
        if h0 == None or c0 == None:
          h0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
          c0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
        
        
        if self.num_layers>1 and h0.shape[0] == 1:
          h0 = torch.stack([h0.squeeze() for i in range(self.num_layers)],dim = 0)
          c0 = torch.stack([c0.squeeze() for i in range(self.num_layers)],dim = 0)
        
        #print(h0.shape)
        
        outputs = torch.empty((batch_size, captions.size(1), 2)).cuda()
        
        
        for t in range(captions.size(1)):
        
            # for the first time step the input is the feature vector
            if t == 0:
                output, (hidden_state, cell_state) = self.lstm_cell(p0.unsqueeze(0), (h0, c0))
            else:
                output, (hidden_state, cell_state) = self.lstm_cell(out.unsqueeze(0), (hidden_state, cell_state))
                
                
            assert h0 != None

            
            emb = self.embedimage(torch.cat([torch.flatten(features,start_dim=1),output.squeeze()],dim=1))
            if t ==0:
              self.longtermMem[:,:,ind]=emb
            img_emb[:, t, :] = emb
            
            
            alph = self.alpha(torch.flatten(img_emb.clone(),start_dim=1))
            outesalpha = img_emb.clone()*alph.unsqueeze(2)
            
            outefl = torch.sum(outesalpha,dim=1)
            combOut = torch.cat([torch.flatten(self.longtermMem,start_dim=1),outefl,img_emb[:, 0, :],emb],dim=1)
            
            out = self.fc_out(combOut)
            
            # build the output tensor

            outputs[:, t, :] = out
        #print(h0.shape,hidden_state.shape)
            
        return 32.0*outputs, hidden_state.detach().clone(), cell_state.detach().clone()#, captions

# %%
a = torch.ones(64,256,50)
b = torch.from_numpy(np.random.randn(50))
c = a*b
print(c[0,1,:])
print(c[1,1,:])
# Out:
# tensor([ 0.5089,  1.0585,  1.0412, -1.2302, -0.0675, -0.5393,  0.1995,  0.3591,
#          0.4443,  1.3669, -0.6580,  0.1996, -0.3765, -0.8311, -0.4110,  0.4567,
#          0.7588,  0.3851,  0.7809,  0.9200, -1.4191, -0.6785,  0.4890, -0.1298,
#          0.3138, -1.7972,  0.1054,  0.0776,  1.7331,  2.4544,  0.2461, -0.7940,
#          0.7578, -1.3571, -1.5151, -1.2676, -0.1639,  0.5813,  1.0705, -0.0794,
#         -1.0454,  0.4000, -0.4473,  0.3456, -0.5274, -1.4667,  1.5450, -1.8244,
#          0.2859,  0.2816], dtype=torch.float64)
# tensor([ 0.5089,  1.0585,  1.0412, -1.2302, -0.0675, -0.5393,  0.1995,  0.3591,
#          0.4443,  1.3669, -0.6580,  0.1996, -0.3765, -0.8311, -0.4110,  0.4567,
#          0.7588,  0.3851,  0.7809,  0.9200, -1.4191, -0.6785,  0.4890, -0.1298,
#          0.3138, -1.7972,  0.1054,  0.0776,  1.7331,  2.4544,  0.2461, -0.7940,
#          0.7578, -1.3571, -1.5151, -1.2676, -0.1639,  0.5813,  1.0705, -0.0794,
#         -1.0454,  0.4000, -0.4473,  0.3456, -0.5274, -1.4667,  1.5450, -1.8244,
#          0.2859,  0.2816], dtype=torch.float64)

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
model = model.train()
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0
# tensor(64.9305, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(49.9933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(41.3122, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(36.2467, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(31.7121, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(26.5347, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(23.0995, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(19.2888, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(18.8761, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(13.0774, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(6.5279, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(5.0738, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(3.7712, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(3.7568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(2.9864, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(3.6106, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(2.6525, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(3.2316, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(5.3589, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(6.8116, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(4.3793, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(4.9994, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(7.8791, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(3.7281, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(4.6878, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(4.7869, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(4.0844, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(5.2250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(3.6622, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(5.3232, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.9763, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.9407, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.9899, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.6510, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.5021, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.2713, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.5622, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.9188, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.5596, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(2.1420, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.1001, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(3.2791, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(5.4842, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.6729, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(3.1504, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.1336, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.2722, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.5516, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.8767, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.9397, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.7302, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.7323, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.9867, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.9507, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.2803, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.5816, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.1193, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.5179, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.2451, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(2.6445, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(3.0151, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.1249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.9914, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.2975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.9030, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.8680, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.4248, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.2818, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.4431, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(6.8587, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(14.8261, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(6.7456, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(5.1364, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(6.7983, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(5.5787, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(4.4038, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.3327, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.1285, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(2.3945, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.9737, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.8973, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.9263, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.7580, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.6713, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.9656, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.4393, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.6791, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.8016, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.7509, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.7548, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.6640, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.7957, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.6607, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.8649, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.8666, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.7587, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.8558, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.6373, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.5450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.9177, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.0602, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.4497, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.2309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.4305, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.2463, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(4.6266, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.6124, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.0503, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.8532, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.8023, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.5272, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.3020, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.8385, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.0365, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.1276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(3.1012, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.3221, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.8504, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(2.5812, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.5674, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.5501, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.5801, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.4589, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.3504, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.9140, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.3454, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.1113, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.8492, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.6360, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.9958, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.5811, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.9947, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.7929, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.4842, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.7364, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.5894, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(1.7859, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(2.8880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(4.4949, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6
# tensor(3.9593, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(4.8639, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(3.5567, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.3847, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.7735, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(3.7407, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(4.6613, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(3.7031, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(5.7633, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(5.1469, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(4.5013, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.3795, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.0651, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.1248, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.2917, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.8385, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.0020, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(2.6006, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.6995, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.7938, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7
# tensor(1.6008, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.4218, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.8568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.7486, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.7194, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.8635, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(2.0848, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.8258, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.6823, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8
# tensor(1.8492, device='cuda:0', grad_fn=<MeanBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-e77106b1da5b> in <module>()
#      11       optimizer.zero_grad()
#      12
# ---> 13       out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
#      14       loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
#      15       writer.add_scalar("Loss/train", loss, epoch)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-4-72855178495e> in forward(self, features, captions, h0, c0, ind)
#      79                 output, (hidden_state, cell_state) = self.lstm_cell(p0.unsqueeze(0), (h0, c0))
#      80             else:
# ---> 81                 output, (hidden_state, cell_state) = self.lstm_cell(out.unsqueeze(0), (hidden_state, cell_state))
#      82
#      83
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     660         if batch_sizes is None:
#     661             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 662                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     663         else:
#     664             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
model = model.train()
for epoch in range (5):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      #print(x.shape,y.shape)

      out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0
# tensor(1.9495, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2305, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.3423, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1116, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.4590, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.3418, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.4493, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.4133, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.3449, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.4166, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.3634, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2073, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2492, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2884, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.3249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.3014, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2755, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1857, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.3737, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2427, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2399, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2895, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2217, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2287, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.3542, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1527, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2065, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2159, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.4652, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.3620, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0937, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.3322, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.3504, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.3759, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1326, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1203, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.3187, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1521, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1997, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1143, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(0.9734, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.3571, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.3685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1887, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2635, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1950, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1961, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2476, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1541, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2731, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2001, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2529, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.6138, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.3498, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2347, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0542, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1001, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(0.9055, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2468, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2735, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2240, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2380, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2632, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0955, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1896, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1769, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0561, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.3030, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1805, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0922, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2376, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.4199, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1700, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1793, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.3519, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(0.9999, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1956, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1200, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2470, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2606, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2766, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1960, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0349, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(0.8655, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0012, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0865, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1665, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.3766, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.4515, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1668, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1931, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2974, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2424, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0030, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0630, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1307, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1369, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.0173, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.2435, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1197, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.1406, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5
# tensor(1.2702, device='cuda:0', grad_fn=<MeanBackward0>)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1de26c34521e> in <module>()
#      16       writer.add_scalar("Loss/train", loss, epoch)
#      17
# ---> 18       loss.backward()
#      19       optimizer.step()
#      20     #print(y[:,0,:2])
#
# /usr/local/lib/python3.7/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     148
#     149
#
# KeyboardInterrupt:

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.000001, betas = (.9,.999))#ideal

# %%
model = model.train()
for epoch in range (5):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      #print(x.shape,y.shape)

      out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0
# tensor(1.2245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0956, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2315, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1481, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1340, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(0.9724, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1577, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(0.9601, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0658, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0387, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2656, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2418, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0470, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(0.9732, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1337, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.2301, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1981, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.1008, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0
# tensor(1.0726, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(0.9174, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0619, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2638, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(0.9725, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1845, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0582, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1426, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(0.9893, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0485, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1695, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0700, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2567, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1133, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2306, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.2411, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0239, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.0220, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1489, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1
# tensor(1.1739, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(0.9184, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1655, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1313, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1117, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1677, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0492, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0882, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1627, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0605, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1578, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1473, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1574, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1373, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.2983, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(0.9232, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1852, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0812, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.0540, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2
# tensor(1.1640, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0036, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1586, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(0.9999, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1815, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0330, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2241, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1176, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1293, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0663, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0161, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1340, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1992, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.1032, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0795, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0583, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0912, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.0349, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3
# tensor(1.2425, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(0.9928, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2569, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1542, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(0.9157, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1159, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(0.9364, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1330, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1360, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2139, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.2221, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0706, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0339, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0532, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0895, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1174, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1733, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1989, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1480, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.0397, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4
# tensor(1.1197, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model = model.eval()
for epoch in range (1):
  loss = None
  for x,y in loader_test:
    h0 = None
    c0 = None
    loss = torch.zeros(19)
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      #print(x.shape,y.shape)

      out, h0, c0 = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      
      loss[i] = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      print(loss[i])
      writer.add_scalar("Loss/val", loss[i],i, epoch)

    #print(y[:,0,:2])
    print('epoch',epoch)
    print('test loss', torch.mean(loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# tensor(0.9681, grad_fn=<SelectBackward>)
# tensor(1.0066, grad_fn=<SelectBackward>)
# tensor(1.0126, grad_fn=<SelectBackward>)
# tensor(0.9353, grad_fn=<SelectBackward>)
# tensor(1.1323, grad_fn=<SelectBackward>)
# tensor(1.0750, grad_fn=<SelectBackward>)
# tensor(1.0005, grad_fn=<SelectBackward>)
# tensor(0.9040, grad_fn=<SelectBackward>)
# tensor(0.8543, grad_fn=<SelectBackward>)
# tensor(1.0166, grad_fn=<SelectBackward>)
# tensor(1.0219, grad_fn=<SelectBackward>)
# tensor(1.1135, grad_fn=<SelectBackward>)
# tensor(1.1325, grad_fn=<SelectBackward>)
# tensor(1.2403, grad_fn=<SelectBackward>)
# tensor(1.1037, grad_fn=<SelectBackward>)
# tensor(1.1030, grad_fn=<SelectBackward>)
# tensor(1.0864, grad_fn=<SelectBackward>)
# tensor(1.1446, grad_fn=<SelectBackward>)
# tensor(1.1015, grad_fn=<SelectBackward>)
# epoch 0
# test loss tensor(1.0502, grad_fn=<MeanBackward0>)

# %%
writer.flush()
writer.close()

# %% [markdown]
# **started** with .0001 then moved to .00001 learning rate (20 epochs)
# finished with .000001 lr, but didn't see much more improvement (total 60 epochs 20,20,20) extra 20 over previous comment

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)
# Out:
# torch.Size([1000, 3]) torch.Size([32, 32])
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
# torch.Size([1000, 3]) torch.Size([32, 32])
